# %%
import numpy as np
import pandas as pd
read_data = pd.read_excel(r"F:\git_project\spider_list\death_company\death_company_info - 副本.xls")
df_data = pd.DataFrame(read_data)
# 计算存活天数
def cal_live_time(start_time,end_time):
    import datetime
    d1 = datetime.datetime.strptime(start_time,'%Y-%m-%d')
    d2 = datetime.datetime.strptime(end_time,'%Y-%m-%d')
    days = (d2-d1).days
    return days

# %%
need_data = df_data.loc[:,['com_name','com_born','com_change_close_date','com_style','com_position','com_tags','com_fund_status_name','com_invsts','death_reason']]

# %%
need_data.head()
# Out:
#   com_name    com_born com_change_close_date   com_style com_position  \
# 0     韦博英语  1996-03-01            2019-10-09      教育语言学习           上海
# 1     我厨生鲜  2014-12-01            2019-12-12    电子商务生鲜食品           上海
# 2    51tou  2014-06-01            2019-08-02  广告营销整合营销传播           上海
# 3     闲鱼懒猫  2017-11-01            2019-06-13   游戏游戏媒体及社区           上海
# 4      尚品网  2008-11-01            2019-07-31     电子商务奢侈品           北京
#
#                                             com_tags com_fund_status_name  \
# 0                     教育/语言学习/教育机构/英语学习/英语培训/外教/泛教育/                 尚未获投
# 1  生鲜/垂直电商/O2O/B2B/B2C/美食社区/本地生活/美食餐饮/电子商务/生鲜食品/半...                   B轮
# 2          服务/广告营销/整合营销传播/大数据营销/精准营销/数字营销/整合营销/广告检测/                 尚未获投
# 3                        游戏/游戏媒体及社区/电子竞技/电竞赛事/游戏/电竞/                 尚未获投
# 4  垂直电商/时尚潮品/闪购/电子商务/化妆品/珠宝首饰/会员制/消费升级/奢侈品/化妆品电商/...                   C轮
#
#                                           com_invsts  death_reason
# 0                                                NaN        现金流断裂/
# 1  集富亚洲JAFCO/LB投资(LB Investment)/新天域资本/谱润投资/远景万方/...   现金流断裂/行业竞争/
# 2                                                NaN         业务调整/
# 3                                                NaN  商业模式匮乏/行业竞争/
# 4                               晨兴资本/成为资本/思伟投资/蓝图创投/   现金流断裂/行业竞争/

# %%
# 计算所有公司的存活时间
f = lambda x:cal_live_time(x.com_born,x.com_change_close_date)
need_data['live_time'] = need_data.apply(f,axis=1)

# %%
need_data.head()
# Out:
#   com_name    com_born com_change_close_date   com_style com_position  \
# 0     韦博英语  1996-03-01            2019-10-09      教育语言学习           上海
# 1     我厨生鲜  2014-12-01            2019-12-12    电子商务生鲜食品           上海
# 2    51tou  2014-06-01            2019-08-02  广告营销整合营销传播           上海
# 3     闲鱼懒猫  2017-11-01            2019-06-13   游戏游戏媒体及社区           上海
# 4      尚品网  2008-11-01            2019-07-31     电子商务奢侈品           北京
#
#                                             com_tags com_fund_status_name  \
# 0                     教育/语言学习/教育机构/英语学习/英语培训/外教/泛教育/                 尚未获投
# 1  生鲜/垂直电商/O2O/B2B/B2C/美食社区/本地生活/美食餐饮/电子商务/生鲜食品/半...                   B轮
# 2          服务/广告营销/整合营销传播/大数据营销/精准营销/数字营销/整合营销/广告检测/                 尚未获投
# 3                        游戏/游戏媒体及社区/电子竞技/电竞赛事/游戏/电竞/                 尚未获投
# 4  垂直电商/时尚潮品/闪购/电子商务/化妆品/珠宝首饰/会员制/消费升级/奢侈品/化妆品电商/...                   C轮
#
#                                           com_invsts  death_reason  live_time
# 0                                                NaN        现金流断裂/       8622
# 1  集富亚洲JAFCO/LB投资(LB Investment)/新天域资本/谱润投资/远景万方/...   现金流断裂/行业竞争/       1837
# 2                                                NaN         业务调整/       1888
# 3                                                NaN  商业模式匮乏/行业竞争/        589
# 4                               晨兴资本/成为资本/思伟投资/蓝图创投/   现金流断裂/行业竞争/       3924

# %%
# 获取生存时间最短的公司
need_data.loc[need_data['live_time'].idxmin(),:]
# Out:
# com_name                                                              第一医生
# com_born                                                        2014-12-01
# com_change_close_date                                           2015-04-01
# com_style                                                         医疗健康寻医诊疗
# com_position                                                            北京
# com_tags                 挂号/诊所/腾讯系/医疗健康/医生服务/寻医诊疗/健康保健/互联网医疗/医疗机构/患者服务/医院/
# com_fund_status_name                                                  尚未获投
# com_invsts                                                             NaN
# death_reason                                                       商业模式匮乏/
# live_time                                                              121
# Name: 5508, dtype: object

# %%
# 获取生存时间最长的公司
need_data.loc[need_data['live_time'].idxmax(),:]
# Out:
# com_name                                           韦博英语
# com_born                                     1996-03-01
# com_change_close_date                        2019-10-09
# com_style                                        教育语言学习
# com_position                                         上海
# com_tags                 教育/语言学习/教育机构/英语学习/英语培训/外教/泛教育/
# com_fund_status_name                               尚未获投
# com_invsts                                          NaN
# death_reason                                     现金流断裂/
# live_time                                          8622
# Name: 0, dtype: object

# %%
# 按照存活天数对数据排序
need_data.sort_values(by='live_time',ascending=False)[:20]
# Out:
#          com_name    com_born com_change_close_date       com_style  \
# 0            韦博英语  1996-03-01            2019-10-09          教育语言学习
# 29           浩沙健身  1997-08-01            2019-06-04        体育运动大众健身
# 5725         中鳖科技  1995-11-01            2014-07-26            金融支付
# 1707        VIP达人  2000-01-01            2017-08-11    本地生活商户服务及信息化
# 1699         四海科技  2000-01-01            2017-08-11     广告营销移动及网络广告
# 1684       08投资论坛  2000-01-01            2017-08-11          金融其他金融
# 5121  ArcNote商务相机  1998-08-01            2015-07-27        工具软件图像视频
# 5518        虹软美妆秀  1998-08-01            2015-02-04        工具软件图像视频
# 305          雕刻时光  2002-11-01            2019-03-21        本地生活美食餐饮
# 4961         马头流量  2000-01-01            2015-07-28       工具软件事项及效率
# 0                    尚未获投        NaN        现金流断裂/       8622
# 29                   尚未获投        NaN           NaN       7977
# 5725                 尚未获投        NaN           NaN       6842
# 1707                  不明确        NaN           NaN       6432
# 1699                  不明确        NaN           NaN       6432
# 1684                  不明确        NaN           NaN       6432
# 5121                 尚未获投        NaN  商业模式匮乏/业务调整/       6204
# 5518                  不明确        NaN    业务调整/行业竞争/       6031
# 305                  尚未获投        NaN           NaN       5984
# 4961                 尚未获投        NaN       商业模式匮乏/       5687
# 5480                 尚未获投        NaN           NaN       5543
# 3163                  不明确        NaN       商业模式匮乏/       5509
# 3196                 尚未获投        NaN           NaN       5483
# 742                  尚未获投        NaN  业务过于分散/业务调整/       5362
# 5678                  不明确        NaN           NaN       5291
# 798                  尚未获投        NaN           NaN       5145
# 5504                  不明确        NaN           NaN       5118
# 6024                  已上市        NaN       商业模式匮乏/       4954
# 1247                 尚未获投        NaN       商业模式匮乏/       4931
# 1233                 尚未获投        NaN       商业模式匮乏/       4931

# %%
# 平均存活时间
need_data['live_time'].mean()
# Out:
# 1293.2704402515724

# %%
import matplotlib.pyplot as plt
from pylab import *
# 设置刻度间隔
from matplotlib.pyplot import MultipleLocator
plt.figure(num=3, figsize=(8, 5),)
mpl.rcParams['font.sans-serif'] = ['SimHei']
plt.hist(need_data['live_time'],color=['red'],label='days')
# 设置x，y轴的间隔
x_major_locator=MultipleLocator(500)
y_major_locator=MultipleLocator(200)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
ax.yaxis.set_major_locator(y_major_locator)
plt.xlim(0,9000)
plt.legend(loc='upper right')
plt.title("公司存活时间直方分布图",fontsize=16)
plt.xlabel('公司存活时间(单位:天)',fontsize=14)
plt.ylabel('公司个数(单位:个)',fontsize=14)
plt.grid(linestyle='-.', alpha=.3)
plt.show()

# %%
# 存活时间TOP20的公司位置统计
live_time_top_20 = need_data.sort_values(by='live_time',ascending=False)[:20]
live_time_top_20['com_position'].value_counts()
# Out:
# 北京    10
# 上海     5
# 浙江     3
# 湖南     1
# 江苏     1
# Name: com_position, dtype: int64

# %%
# 统计所有公司位置的总数
com_position = need_data['com_position'].value_counts()
com_position = com_position.head(10)
name = np.array(list(com_position.index))
num = np.array(list(com_position.values))
plt.figure(figsize=(16,6))

com_position.plot(kind='bar',color='g',grid=True,rot=25)
plt.title('死亡公司分布情况(TOP10)',fontsize=20)
plt.xlabel('公司地理位置',fontsize=16)
plt.ylabel('公司数量',fontsize=16)
# plt.savefig('.\可视化图\position_name.jpg')

for a, b in zip(name, num):
    plt.text(a, b, ha='center', va='bottom', fontsize=11)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-139-21d144a996d5> in <module>
#      13
#      14 for a, b in zip(name, num):
# ---> 15     plt.text(a, b, ha='center')
#      16 plt.show()
#
# TypeError: text() missing 1 required positional argument: 's'
